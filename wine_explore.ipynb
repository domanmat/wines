# %%
import sys                
print(sys.executable)
# Out:
# c:\Users\Mateusz\PycharmProjects\wines\.venv\Scripts\python.exe

# %%
import importlib.util                                   
print(importlib.util.find_spec("pkg_resources"))
# Out:
# None

# %%
import pandas as pd
df=pd.read_csv("wine_reviews-2026-04-11-23-44.csv")

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Wine Reviews EDA", explorative=True)
profile.to_notebook_iframe()

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import dtale
#       2 dtale.show(df)
#
# ModuleNotFoundError: No module named 'dtale'
